# %% [markdown]
# # Logan T Hernandez

# %% [markdown]
# ## Research question/interests
#
# **My part of the project will be exploring the change in housing prices, new housing construction, and population of canadian metropolitan areas over time.**
#
# My research question is related to the change in available housing, cost, and population of canadian metropolitan areas. I believe that everyone under 30 is worried about the state of the housing market and availability of affordable living. With this concern in mind, I plan to visualize how the market has changed over time relative to population increases of metropolitan hubs. Since hubs provide the greatest opportunity for career advancement, people who want to earn high paying jobs often relocate to hubs; however, the cost of living in the hub also dictates its affordability, with the highest C.O.L. expenditure being housing. Therefore, my analysis will also attempt to determine the most affordable canadian metropolitan hub respective of housing cost and inventory.

# %% [markdown]
# ## Part 1, Working (mainly) with PopEstimate DF
#
# ### Data Loading

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_theme(style='whitegrid', font_scale=2)

DailyInterestRate = pd.read_csv("../data/raw/DailyInterestRates/DailyInterestRates.csv")
NewHousingPIndex = pd.read_csv("../data/raw/NewHousingPIndex/NewHousingPIndex.csv")
NewInventory = pd.read_csv("../data/raw/NewInventory/NewInventory.csv", low_memory = False)
PopEstimate = pd.read_csv("../data/raw/PopEstimate/PopEstimate.csv")

# %%
PopEstimate.head(5)
# Out:
#    REF_DATE     GEO          DGUID         Sex     Age group      UOM  UOM_ID  \
# 0      2001  Canada  2016A00001124  Both sexes      All ages  Persons     249
# 1      2001  Canada  2016A00001124  Both sexes  0 to 4 years  Persons     249
# 2      2001  Canada  2016A00001124  Both sexes       0 years  Persons     249
# 3      2001  Canada  2016A00001124  Both sexes        1 year  Persons     249
# 4      2001  Canada  2016A00001124  Both sexes       2 years  Persons     249
#
#   SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE       VALUE  STATUS  \
# 0         units          0  v1462635598    178.1.1  31020902.0     NaN
# 1         units          0  v1462635576    178.1.2   1754354.0     NaN
# 2         units          0  v1462635484    178.1.3    328494.0     NaN
# 3         units          0  v1462635485    178.1.4    345259.0     NaN
# 4         units          0  v1462635486    178.1.5    349563.0     NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         0
# 2     NaN         NaN         0
# 3     NaN         NaN         0
# 4     NaN         NaN         0

# %% [markdown]
# ### Data Cleaning
# Theres quite a few columns here that are going to be erraneous for my analysis, so I'm first going to drop the columns that are not directly related to the general geographical location and to the population, and age of populants.

# %%
PE_Wrangled = PopEstimate.drop(columns=['DGUID', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'], axis=1).reset_index().drop(columns=["index"])
PE_Wrangled.sample(10)
# Out:
#          REF_DATE                                                GEO  \
# 1300042      2022                           Winnipeg (CMA), Manitoba
# 596329       2010                         Medicine Hat (CA), Alberta
# 911007       2015                      Duncan (CA), British Columbia
# 542621       2009                      Duncan (CA), British Columbia
# 793527       2013  All areas outside census metropolitan areas an...
# 406439       2007                               Kenora (CA), Ontario
# 454318       2008                            Shawinigan (CA), Quebec
# 10533        2001                           Winnipeg (CMA), Manitoba
# 122161       2002  Area outside census metropolitan areas and cen...
# 1074892      2018                              Cobourg (CA), Ontario
#
#                 Sex       Age group      UOM    VALUE
# 1300042  Both sexes        67 years  Persons   9384.0
# 596329        Males        44 years  Persons    497.0
# 911007        Males        75 years  Persons    190.0
# 542621      Females        41 years  Persons    234.0
# 793527   Both sexes        21 years  Persons  71296.0
# 406439   Both sexes        23 years  Persons    156.0
# 454318      Females        55 years  Persons    498.0
# 10533         Males        55 years  Persons   3733.0
# 122161   Both sexes  25 to 29 years  Persons   1743.0
# 1074892       Males        84 years  Persons     71.0

# %% [markdown]
# This is a lot more concise already, and only includes values explicitly related to my analysis. Interestingly, the unit of measurement (UOM) column provides an additional level of data formatting that i can utilize later, as it will allow me to filter the data by average ages. I'm not sure if I will use this yet, however the analysis to do so will simply filter the wrangled dataset by UOM value == Persons or years. The same filter can be applied by using the age group category, however it will provide more explicit filtration as this category also inlcudes all age groups of each city's population. As for now, I will conduct some additional exploratory analysis using plots.

# %%
PE_GB_GEO = PE_Wrangled.groupby('GEO').sum().reset_index().sort_values(by=['VALUE'], ascending=False)
PE_GB_GEO.head(20)
# Out:
# /var/folders/v9/f2hd85ns75q9chg2z10c7wcc0000gn/T/ipykernel_42164/188684402.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   PE_GB_GEO = PE_Wrangled.groupby('GEO').sum().reset_index().sort_values(by=['VALUE'], ascending=False)
#                                                    GEO  REF_DATE         VALUE
# 35                                              Canada  15267285  6.088087e+09
# 3    All census metropolitan areas and census agglo...  15267285  5.033420e+09
# 4                All census metropolitan areas, Canada  15267285  4.283533e+09
# 1    All areas outside census metropolitan areas an...  15267285  1.054672e+09
# 158                             Toronto (CMA), Ontario  15267285  1.017752e+09
# 2                    All census agglomerations, Canada  15267285  7.498925e+08
# 95                              Montréal (CMA), Quebec  15267285  7.036907e+08
# 162                  Vancouver (CMA), British Columbia  15267285  4.241699e+08
# 16   Area outside census metropolitan areas and cen...  15267285  2.706236e+08
# 14   Area outside census metropolitan areas and cen...  15267285  2.490646e+08
# 107            Ottawa - Gatineau (CMA), Ontario/Quebec  15267285  2.278083e+08
# 29                              Calgary (CMA), Alberta  15267285  2.269135e+08
# 55                             Edmonton (CMA), Alberta  15267285  2.165584e+08
# 106     Ottawa - Gatineau (CMA), Ontario part, Ontario  15267285  1.720515e+08
# 123                               Québec (CMA), Quebec  15267285  1.360221e+08
# 173                           Winnipeg (CMA), Manitoba  15267285  1.345632e+08
# 68                             Hamilton (CMA), Ontario  15267285  1.316121e+08
# 6    Area outside census metropolitan areas and cen...  15267285  1.282397e+08
# 7    Area outside census metropolitan areas and cen...  15267285  9.698174e+07
# 81     Kitchener - Cambridge - Waterloo (CMA), Ontario  15267285  9.163376e+07

# %% [markdown]
# This provides us with a brief description of the largest metropolitan areas in canada during the past 20 years on a combined value of total population summation from each year. Now, Ill start dropping the useless rows. First off, I'll drop 'Canada' and all other aggregated rows.

# %%
PE_ordered_filtered = PE_GB_GEO.drop(PE_GB_GEO[PE_GB_GEO.GEO.isin(['Canada',
                                                                'All areas outside census metropolitan areas and census agglomerations, Canada',
                                                                'All census agglomerations, Canada',
                                                                'All census metropolitan areas and census agglomerations, Canada',
                                                                'All census metropolitan areas, Canada','Area outside census metropolitan areas and census agglomerations, Alberta',
                                                                'Area outside census metropolitan areas and census agglomerations, British Columbia',
                                                                'Area outside census metropolitan areas and census agglomerations, Manitoba',
                                                                'Area outside census metropolitan areas and census agglomerations, New Brunswick',
                                                                'Area outside census metropolitan areas and census agglomerations, Newfoundland and Labrador',
                                                                'Area outside census metropolitan areas and census agglomerations, Northwest Territories',
                                                                'Area outside census metropolitan areas and census agglomerations, Nova Scotia',
                                                                'Area outside census metropolitan areas and census agglomerations, Nunavut',
                                                                'Area outside census metropolitan areas and census agglomerations, Ontario',
                                                                'Area outside census metropolitan areas and census agglomerations, Prince Edward Island',
                                                                'Area outside census metropolitan areas and census agglomerations, Quebec',
                                                                'Area outside census metropolitan areas and census agglomerations, Saskatchewan',
                                                                'Area outside census metropolitan areas and census agglomerations, Yukon',
                                                                'Ottawa - Gatineau (CMA), Ontario part, Ontario',
                                                                'Ottawa - Gatineau (CMA), Quebec part, Quebec'])].index).head(30).reset_index().drop(columns=["index"])
PE_ordered_filtered
# Out:
#                                                 GEO  REF_DATE         VALUE
# 0                            Toronto (CMA), Ontario  15267285  1.017752e+09
# 1                            Montréal (CMA), Quebec  15267285  7.036907e+08
# 2                 Vancouver (CMA), British Columbia  15267285  4.241699e+08
# 3           Ottawa - Gatineau (CMA), Ontario/Quebec  15267285  2.278083e+08
# 4                            Calgary (CMA), Alberta  15267285  2.269135e+08
# 5                           Edmonton (CMA), Alberta  15267285  2.165584e+08
# 6                              Québec (CMA), Quebec  15267285  1.360221e+08
# 7                          Winnipeg (CMA), Manitoba  15267285  1.345632e+08
# 8                           Hamilton (CMA), Ontario  15267285  1.316121e+08
# 9   Kitchener - Cambridge - Waterloo (CMA), Ontario  15267285  9.163376e+07
# 10                            London (CMA), Ontario  15267285  8.767920e+07
# 11          St. Catharines - Niagara (CMA), Ontario  15267285  7.230773e+07
# 12                       Halifax (CMA), Nova Scotia  15267285  7.159176e+07
# 13                            Oshawa (CMA), Ontario  15267285  6.535429e+07
# 14                 Victoria (CMA), British Columbia  15267285  6.397584e+07
# 15                           Windsor (CMA), Ontario  15267285  5.925425e+07
# 16                    Saskatoon (CMA), Saskatchewan  15267285  4.933559e+07
# 17                       Regina (CMA), Saskatchewan  15267285  3.985399e+07
# 18                         Sherbrooke (CMA), Quebec  15267285  3.605720e+07
# 19      St. John's (CMA), Newfoundland and Labrador  15267285  3.495736e+07
# 20                            Barrie (CMA), Ontario  15267285  3.405962e+07
# 21                  Kelowna (CMA), British Columbia  15267285  3.313070e+07
# 22     Abbotsford - Mission (CMA), British Columbia  15267285  3.134526e+07
# 23                   Greater Sudbury (CMA), Ontario  15267285  2.959469e+07
# 24                          Kingston (CMA), Ontario  15267285  2.888366e+07
# 25                           Saguenay (CMA), Quebec  15267285  2.829668e+07
# 26                     Trois-Rivières (CMA), Quebec  15267285  2.686730e+07
# 27                            Guelph (CMA), Ontario  15267285  2.616094e+07
# 28                     Moncton (CMA), New Brunswick  15267285  2.493449e+07
# 29                         Brantford (CMA), Ontario  15267285  2.473862e+07

# %% [markdown]
# ### Minor Visual EDA
# Great, now I can visualize the 30 largest metropolitan areas in Canada from their combined population counts for the past 20 years. These are the locations that I will assess in my analysis of housing inventory and price index.

# %%
sns.set_theme(style='whitegrid', font_scale=0.8)
sns.catplot(data=PE_ordered_filtered, y='GEO', x='VALUE', kind='bar')
n=None

# %%
NewHousingPIndex.sample(10)
# Out:
#       REF_DATE                                            GEO           DGUID  \
# 57718  2021-01                     Victoria, British Columbia    2011S0503935
# 40743  2009-04                St. Catharines-Niagara, Ontario    2011S0503539
# 35888  2005-12                      Newfoundland and Labrador     2016A000210
# 31375  2002-10                                Oshawa, Ontario    2011S0503532
# 4820   1984-05                                    Nova Scotia     2016A000212
# 4669   1984-03                               British Columbia     2016A000259
# 17418  1993-02                                    Nova Scotia     2016A000212
# 5617   1984-11                        Saskatoon, Saskatchewan    2011S0503725
# 25242  1998-07                               Montréal, Quebec    2011S0503462
# 7371   1986-02  Ottawa-Gatineau, Ontario part, Ontario/Quebec  2011S050335505
#
#       New housing price indexes                UOM  UOM_ID SCALAR_FACTOR  \
# 57718                House only  Index, 201612=100     347         units
# 40743    Total (house and land)  Index, 201612=100     347         units
# 35888                 Land only  Index, 201612=100     347         units
# 31375                House only  Index, 201612=100     347         units
# 4820                  Land only  Index, 201612=100     347         units
# 4669                 House only  Index, 201612=100     347         units
# 17418    Total (house and land)  Index, 201612=100     347         units
# 5617                 House only  Index, 201612=100     347         units
# 25242    Total (house and land)  Index, 201612=100     347         units
# 7371     Total (house and land)  Index, 201612=100     347         units
#
#        SCALAR_ID      VECTOR  COORDINATE  VALUE STATUS  SYMBOL  TERMINATED  \
# 57718          0  v111955560        40.2  109.1    NaN     NaN         NaN
# 40743          0  v111955505        22.1   85.7    NaN     NaN         NaN
# 35888          0  v111955450         3.3   55.5      E     NaN         NaN
# 31375          0  v111955497        19.2    NaN     ..     NaN         NaN
# 4820           0  v111955462         7.3    NaN     ..     NaN         NaN
# 4669           0  v111955551        37.2    NaN     ..     NaN         NaN
# 17418          0  v111955460         7.1   56.6    NaN     NaN         NaN
# 5617           0  v111955539        33.2   37.1    NaN     NaN         NaN
# 25242          0  v111955484        15.1   54.7    NaN     NaN         NaN
# 7371           0  v111955493        18.1   44.3    NaN     NaN         NaN
#
#        DECIMALS
# 57718         1
# 40743         1
# 35888         1
# 31375         1
# 4820          1
# 4669          1
# 17418         1
# 5617          1
# 25242         1
# 7371          1

# %% [markdown]
# ### More Data Cleaning
#
# Similar to before, there's quite a few columns here that are going to be erraneous for my analysis, so I'm first going to drop the columns that are not directly related to the general geographical location and to the housing price.

# %%
NewHousingPIndex_Wrangled = NewHousingPIndex.drop(columns=['DGUID', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'], axis=1).reset_index().drop(columns=["index"]) 
NewHousingPIndex_Wrangled
# Out:
#       REF_DATE                          GEO New housing price indexes  \
# 0      1981-01                       Canada    Total (house and land)
# 1      1981-01                       Canada                House only
# 2      1981-01                       Canada                 Land only
# 3      1981-01              Atlantic Region    Total (house and land)
# 4      1981-01              Atlantic Region                House only
# ...        ...                          ...                       ...
# 60475  2022-12  Vancouver, British Columbia                House only
# 60476  2022-12  Vancouver, British Columbia                 Land only
# 60477  2022-12   Victoria, British Columbia    Total (house and land)
# 60478  2022-12   Victoria, British Columbia                House only
# 60479  2022-12   Victoria, British Columbia                 Land only
#
#                      UOM  VALUE
# 0      Index, 201612=100   38.2
# 1      Index, 201612=100   36.1
# 2      Index, 201612=100   40.6
# 3      Index, 201612=100    NaN
# 4      Index, 201612=100    NaN
# ...                  ...    ...
# 60475  Index, 201612=100  126.8
# 60476  Index, 201612=100  121.4
# 60477  Index, 201612=100  125.0
# 60478  Index, 201612=100  131.9
# 60479  Index, 201612=100  110.8
#
# [60480 rows x 5 columns]

# %% [markdown]
# This is looking better, however there's way too much data compared to what I need for the analysis. My population estimates start in 2001, so I'm going to drop all data for the housing price index prior to 2001 after I ensure that the dates are correctly displayed in datetime format.

# %%
NewHousingPIndex_Wrangled['REF_DATE'] = pd.to_datetime(NewHousingPIndex_Wrangled['REF_DATE'])

NHPI_W_v2 = NewHousingPIndex_Wrangled[~(NewHousingPIndex_Wrangled['REF_DATE'] < '2001-01-01')].reset_index().drop(columns=["index"])
NHPI_W_v2
# Out:
#         REF_DATE                          GEO New housing price indexes  \
# 0     2001-01-01                       Canada    Total (house and land)
# 1     2001-01-01                       Canada                House only
# 2     2001-01-01                       Canada                 Land only
# 3     2001-01-01              Atlantic Region    Total (house and land)
# 4     2001-01-01              Atlantic Region                House only
# ...          ...                          ...                       ...
# 31675 2022-12-01  Vancouver, British Columbia                House only
# 31676 2022-12-01  Vancouver, British Columbia                 Land only
# 31677 2022-12-01   Victoria, British Columbia    Total (house and land)
# 31678 2022-12-01   Victoria, British Columbia                House only
# 31679 2022-12-01   Victoria, British Columbia                 Land only
#
#                      UOM  VALUE
# 0      Index, 201612=100   58.7
# 1      Index, 201612=100   55.5
# 2      Index, 201612=100   67.4
# 3      Index, 201612=100   64.2
# 4      Index, 201612=100   65.7
# ...                  ...    ...
# 31675  Index, 201612=100  126.8
# 31676  Index, 201612=100  121.4
# 31677  Index, 201612=100  125.0
# 31678  Index, 201612=100  131.9
# 31679  Index, 201612=100  110.8
#
# [31680 rows x 5 columns]

# %% [markdown]
# At this point im making a decision on the data I wish to use for the housing price, available to me are the cost of the house and the land and the combined total, I think it would be more applicable if the combined price was used as it would encompass inflation from both angles (I also will rename it as a new variable in case i go back on this decision later).

# %%
NHPI_W_v3 = NHPI_W_v2.drop(NHPI_W_v2[NHPI_W_v2['New housing price indexes'].isin(['House only','Land only'])].index).reset_index().drop(columns=["index"])
NHPI_W_v3
# Out:
#         REF_DATE                                    GEO  \
# 0     2001-01-01                                 Canada
# 1     2001-01-01                        Atlantic Region
# 2     2001-01-01              Newfoundland and Labrador
# 3     2001-01-01  St. John's, Newfoundland and Labrador
# 4     2001-01-01                   Prince Edward Island
# ...          ...                                    ...
# 10555 2022-12-01                      Edmonton, Alberta
# 10556 2022-12-01                       British Columbia
# 10557 2022-12-01              Kelowna, British Columbia
# 10558 2022-12-01            Vancouver, British Columbia
# 10559 2022-12-01             Victoria, British Columbia
#
#       New housing price indexes                UOM  VALUE
# 0        Total (house and land)  Index, 201612=100   58.7
# 1        Total (house and land)  Index, 201612=100   64.2
# 2        Total (house and land)  Index, 201612=100   49.5
# 3        Total (house and land)  Index, 201612=100   49.5
# 4        Total (house and land)  Index, 201612=100   85.7
# ...                         ...                ...    ...
# 10555    Total (house and land)  Index, 201612=100  109.5
# 10556    Total (house and land)  Index, 201612=100  127.6
# 10557    Total (house and land)  Index, 201612=100  123.4
# 10558    Total (house and land)  Index, 201612=100  128.2
# 10559    Total (house and land)  Index, 201612=100  125.0
#
# [10560 rows x 5 columns]

# %% [markdown]
# ### Much more Data cleaning/processing
# Great, now I need to explore the dataset relative to GEO and make a comparison to the population data previously explored. To do this im going to transfer the sorted GEO regions of both the new housing price index and the population index to lists, then cross reference both lists to find the unique regions to each list to determine which regions I have data for. This way I can eliminate the regions with insufficent data or rename the regions if the naming style used between each set differs slightly. I decided that this will be a useful function to have, so I wrote a function named unique_regions, which can do this for me.

# %%
import sys 
sys.path.append('..')
from analysis.code import project_functions2 as pf2

# %%
pf2.unique_regions?
# Out:
# Signature: pf2.unique_regions(*dfs, col_name='GEO')
# Docstring:
# Takes pandas dataframes and a conserved region column name and returns a list of sets,
# with each set in the list containing the unique regions per given dataframe.
#
# Parameters:
# *dfs (pandas.DataFrame): specified dataframes containing a column with conserved name.
# col_name (str): The name of the column containing the region names. (Default is 'GEO').
#
# Returns:
# list: A list of sets, where each set contains the unique regions for a given dataframe.
# The first set contains regions unique to the first dataframe, the second set contains regions unique
# to the second dataframe, etc.
# File:      ~/github-classroom/ubco-W2022T2-data301/project-group-group01/analysis/code/project_functions2.py
# Type:      function

# %%
pf2.unique_regions(NHPI_W_v3, PE_ordered_filtered, col_name='GEO')
# Out:
# [{'Alberta',
#   'Atlantic Region',
#   'British Columbia',
#   'Calgary, Alberta',
#   'Canada',
#   'Charlottetown, Prince Edward Island',
#   'Edmonton, Alberta',
#   'Greater Sudbury, Ontario',
#   'Guelph, Ontario',
#   'Halifax, Nova Scotia',
#   'Hamilton, Ontario',
#   'Kelowna, British Columbia',
#   'Kitchener-Cambridge-Waterloo, Ontario',
#   'London, Ontario',
#   'Manitoba',
#   'Montréal, Quebec',
#   'New Brunswick',
#   'Newfoundland and Labrador',
#   'Nova Scotia',
#   'Ontario',
#   'Oshawa, Ontario',
#   'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#   'Ottawa-Gatineau, Quebec part, Ontario/Quebec',
#   'Prairie Region',
#   'Prince Edward Island',
#   'Quebec',
#   'Québec, Quebec',
#   'Regina, Saskatchewan',
#   'Saint John, Fredericton, and Moncton, New Brunswick',
#   'Saskatchewan',
#   'Saskatoon, Saskatchewan',
#   'Sherbrooke, Quebec',
#   'St. Catharines-Niagara, Ontario',
#   "St. John's, Newfoundland and Labrador",
#   'Toronto, Ontario',
#   'Trois-Rivières, Quebec',
#   'Vancouver, British Columbia',
#   'Victoria, British Columbia',
#   'Windsor, Ontario',
#   'Winnipeg, Manitoba'},
#  {'Abbotsford - Mission (CMA), British Columbia',
#   'Barrie (CMA), Ontario',
#   'Brantford (CMA), Ontario',
#   'Calgary (CMA), Alberta',
#   'Edmonton (CMA), Alberta',
#   'Greater Sudbury (CMA), Ontario',
#   'Guelph (CMA), Ontario',
#   'Halifax (CMA), Nova Scotia',
#   'Hamilton (CMA), Ontario',
#   'Kelowna (CMA), British Columbia',
#   'Kingston (CMA), Ontario',
#   'Kitchener - Cambridge - Waterloo (CMA), Ontario',
#   'London (CMA), Ontario',
#   'Moncton (CMA), New Brunswick',
#   'Montréal (CMA), Quebec',
#   'Oshawa (CMA), Ontario',
#   'Ottawa - Gatineau (CMA), Ontario/Quebec',
#   'Québec (CMA), Quebec',
#   'Regina (CMA), Saskatchewan',
#   'Saguenay (CMA), Quebec',
#   'Saskatoon (CMA), Saskatchewan',
#   'Sherbrooke (CMA), Quebec',
#   'St. Catharines - Niagara (CMA), Ontario',
#   "St. John's (CMA), Newfoundland and Labrador",
#   'Toronto (CMA), Ontario',
#   'Trois-Rivières (CMA), Quebec',
#   'Vancouver (CMA), British Columbia',
#   'Victoria (CMA), British Columbia',
#   'Windsor (CMA), Ontario',
#   'Winnipeg (CMA), Manitoba'}]

# %% [markdown]
# From this comparison, I can see that most of the same areas are listed with the only difference in their names being "(CMA)" and extra space between dashes for some, I will now rename all items in the PopEstimate dataset to their proper names without the "(CMA)" or extra space

# %%
PE_ordered_filtered["GEO"] = PE_ordered_filtered["GEO"].str.replace(r'\(CMA\)', '').str.strip().str.replace(r' ,', ',').str.strip().str.replace(r' - ', '-').str.strip()
PE_ordered_filtered.to_csv("../data/processed/PE_ordered_filtered.csv")
PE_ordered_filtered
# Out:
# /var/folders/v9/f2hd85ns75q9chg2z10c7wcc0000gn/T/ipykernel_42164/1648971501.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   PE_ordered_filtered["GEO"] = PE_ordered_filtered["GEO"].str.replace(r'\(CMA\)', '').str.strip().str.replace(r' ,', ',').str.strip().str.replace(r' - ', '-').str.strip()
#                                       GEO  REF_DATE         VALUE
# 0                        Toronto, Ontario  15267285  1.017752e+09
# 1                        Montréal, Quebec  15267285  7.036907e+08
# 2             Vancouver, British Columbia  15267285  4.241699e+08
# 3         Ottawa-Gatineau, Ontario/Quebec  15267285  2.278083e+08
# 4                        Calgary, Alberta  15267285  2.269135e+08
# 5                       Edmonton, Alberta  15267285  2.165584e+08
# 6                          Québec, Quebec  15267285  1.360221e+08
# 7                      Winnipeg, Manitoba  15267285  1.345632e+08
# 8                       Hamilton, Ontario  15267285  1.316121e+08
# 9   Kitchener-Cambridge-Waterloo, Ontario  15267285  9.163376e+07
# 10                        London, Ontario  15267285  8.767920e+07
# 11        St. Catharines-Niagara, Ontario  15267285  7.230773e+07
# 12                   Halifax, Nova Scotia  15267285  7.159176e+07
# 13                        Oshawa, Ontario  15267285  6.535429e+07
# 14             Victoria, British Columbia  15267285  6.397584e+07
# 15                       Windsor, Ontario  15267285  5.925425e+07
# 16                Saskatoon, Saskatchewan  15267285  4.933559e+07
# 17                   Regina, Saskatchewan  15267285  3.985399e+07
# 18                     Sherbrooke, Quebec  15267285  3.605720e+07
# 19  St. John's, Newfoundland and Labrador  15267285  3.495736e+07
# 20                        Barrie, Ontario  15267285  3.405962e+07
# 21              Kelowna, British Columbia  15267285  3.313070e+07
# 22   Abbotsford-Mission, British Columbia  15267285  3.134526e+07
# 23               Greater Sudbury, Ontario  15267285  2.959469e+07
# 24                      Kingston, Ontario  15267285  2.888366e+07
# 25                       Saguenay, Quebec  15267285  2.829668e+07
# 26                 Trois-Rivières, Quebec  15267285  2.686730e+07
# 27                        Guelph, Ontario  15267285  2.616094e+07
# 28                 Moncton, New Brunswick  15267285  2.493449e+07
# 29                     Brantford, Ontario  15267285  2.473862e+07

# %% [markdown]
# #### Yes! It worked!
# Now, I will recheck the unique lists and see which areas still are not conserved between datasets. I am also ignoring the provinces/regions since they are not applicable to my analysis.

# %%
pf2.unique_regions(NHPI_W_v3, PE_ordered_filtered, col_name='GEO')
# Out:
# [{'Alberta',
#   'Atlantic Region',
#   'British Columbia',
#   'Canada',
#   'Charlottetown, Prince Edward Island',
#   'Manitoba',
#   'New Brunswick',
#   'Newfoundland and Labrador',
#   'Nova Scotia',
#   'Ontario',
#   'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#   'Ottawa-Gatineau, Quebec part, Ontario/Quebec',
#   'Prairie Region',
#   'Prince Edward Island',
#   'Quebec',
#   'Saint John, Fredericton, and Moncton, New Brunswick',
#   'Saskatchewan'},
#  {'Abbotsford-Mission, British Columbia',
#   'Barrie, Ontario',
#   'Brantford, Ontario',
#   'Kingston, Ontario',
#   'Moncton, New Brunswick',
#   'Ottawa-Gatineau, Ontario/Quebec',
#   'Saguenay, Quebec'}]

# %% [markdown]
# Considering that the remaining unique items either have to do with Ottawa-Gatineau and its strange provincial border or the grouping of St. John, Fredericton, and Moncton or metro areas that for some reason just weren't detailed in the new house price index, I am on the right track. I think the least difficult solution to the remaining problem items is to simply drop them, as the majority of them were not high on the bar chart for population index, and my assessment already will rank the top 20+ metropolitan areas. To do this, I will first print the final sorted list of PopEstimate cities so I can refilter the original pre-summed dataset.

# %%
PE_ordered_filtered_v2 = PE_ordered_filtered.drop(PE_ordered_filtered[PE_ordered_filtered.GEO.isin(['Barrie, Ontario',
                                                                                           'Abbotsford-Mission, British Columbia',
                                                                                           'Kingston, Ontario', 'Ottawa-Gatineau, Ontario/Quebec',
                                                                                           'Saguenay, Quebec', 'Brantford, Ontario',
                                                                                           'Moncton, New Brunswick'])].index).reset_index().drop(columns=["index"])
PE_ordered_filtered_v2
# Out:
#                                       GEO  REF_DATE         VALUE
# 0                        Toronto, Ontario  15267285  1.017752e+09
# 1                        Montréal, Quebec  15267285  7.036907e+08
# 2             Vancouver, British Columbia  15267285  4.241699e+08
# 3                        Calgary, Alberta  15267285  2.269135e+08
# 4                       Edmonton, Alberta  15267285  2.165584e+08
# 5                          Québec, Quebec  15267285  1.360221e+08
# 6                      Winnipeg, Manitoba  15267285  1.345632e+08
# 7                       Hamilton, Ontario  15267285  1.316121e+08
# 8   Kitchener-Cambridge-Waterloo, Ontario  15267285  9.163376e+07
# 9                         London, Ontario  15267285  8.767920e+07
# 10        St. Catharines-Niagara, Ontario  15267285  7.230773e+07
# 11                   Halifax, Nova Scotia  15267285  7.159176e+07
# 12                        Oshawa, Ontario  15267285  6.535429e+07
# 13             Victoria, British Columbia  15267285  6.397584e+07
# 14                       Windsor, Ontario  15267285  5.925425e+07
# 15                Saskatoon, Saskatchewan  15267285  4.933559e+07
# 16                   Regina, Saskatchewan  15267285  3.985399e+07
# 17                     Sherbrooke, Quebec  15267285  3.605720e+07
# 18  St. John's, Newfoundland and Labrador  15267285  3.495736e+07
# 19              Kelowna, British Columbia  15267285  3.313070e+07
# 20               Greater Sudbury, Ontario  15267285  2.959469e+07
# 21                 Trois-Rivières, Quebec  15267285  2.686730e+07
# 22                        Guelph, Ontario  15267285  2.616094e+07

# %%
sorted(PE_ordered_filtered_v2['GEO'].unique().tolist())
# Out:
# ['Calgary, Alberta',
#  'Edmonton, Alberta',
#  'Greater Sudbury, Ontario',
#  'Guelph, Ontario',
#  'Halifax, Nova Scotia',
#  'Hamilton, Ontario',
#  'Kelowna, British Columbia',
#  'Kitchener-Cambridge-Waterloo, Ontario',
#  'London, Ontario',
#  'Montréal, Quebec',
#  'Oshawa, Ontario',
#  'Québec, Quebec',
#  'Regina, Saskatchewan',
#  'Saskatoon, Saskatchewan',
#  'Sherbrooke, Quebec',
#  'St. Catharines-Niagara, Ontario',
#  "St. John's, Newfoundland and Labrador",
#  'Toronto, Ontario',
#  'Trois-Rivières, Quebec',
#  'Vancouver, British Columbia',
#  'Victoria, British Columbia',
#  'Windsor, Ontario',
#  'Winnipeg, Manitoba']

# %% [markdown]
# Okay, now these are the final conserved cities that I will use for my analysis that appear in both the PopEstimate dataset along with the NewHousingPriceIndex dataset. From here I can backtrack and remake the original datasets to just include these cities, and avoid summing the original values to keep the reference dates intact. I believe the best course of action will be to then create a pairplot of the change in population and housive availability between each major city over the year range of 2001-2022. Then I can extract the rate of change which can differentially be used as an estimate to determine the metropolitan hub with the best population to availibility index.

# %%
PE_Wrangled.reset_index().drop(columns=['index'])
# Out:
#          REF_DATE                                                GEO  \
# 0            2001                                             Canada
# 1            2001                                             Canada
# 2            2001                                             Canada
# 3            2001                                             Canada
# 4            2001                                             Canada
# ...           ...                                                ...
# 1351015      2022  Area outside census metropolitan areas and cen...
# 1351016      2022  Area outside census metropolitan areas and cen...
# 1351017      2022  Area outside census metropolitan areas and cen...
# 1351018      2022  Area outside census metropolitan areas and cen...
# 1351019      2022  Area outside census metropolitan areas and cen...
#
#                 Sex           Age group      UOM       VALUE
# 0        Both sexes            All ages  Persons  31020902.0
# 1        Both sexes        0 to 4 years  Persons   1754354.0
# 2        Both sexes             0 years  Persons    328494.0
# 3        Both sexes              1 year  Persons    345259.0
# 4        Both sexes             2 years  Persons    349563.0
# ...             ...                 ...      ...         ...
# 1351015     Females       0 to 14 years  Persons      6120.0
# 1351016     Females      15 to 64 years  Persons     12898.0
# 1351017     Females  65 years and older  Persons       762.0
# 1351018     Females          Median age    Years        26.6
# 1351019     Females         Average age    Years        28.9
#
# [1351020 rows x 6 columns]

# %%
PE_Wrangled = PE_Wrangled.drop(PE_Wrangled[PE_Wrangled.GEO.isin(['Canada',
                                                                'All areas outside census metropolitan areas and census agglomerations, Canada',
                                                                'All census agglomerations, Canada',
                                                                'All census metropolitan areas and census agglomerations, Canada',
                                                                'All census metropolitan areas, Canada','Area outside census metropolitan areas and census agglomerations, Alberta',
                                                                'Area outside census metropolitan areas and census agglomerations, British Columbia',
                                                                'Area outside census metropolitan areas and census agglomerations, Manitoba',
                                                                'Area outside census metropolitan areas and census agglomerations, New Brunswick',
                                                                'Area outside census metropolitan areas and census agglomerations, Newfoundland and Labrador',
                                                                'Area outside census metropolitan areas and census agglomerations, Northwest Territories',
                                                                'Area outside census metropolitan areas and census agglomerations, Nova Scotia',
                                                                'Area outside census metropolitan areas and census agglomerations, Nunavut',
                                                                'Area outside census metropolitan areas and census agglomerations, Ontario',
                                                                'Area outside census metropolitan areas and census agglomerations, Prince Edward Island',
                                                                'Area outside census metropolitan areas and census agglomerations, Quebec',
                                                                'Area outside census metropolitan areas and census agglomerations, Saskatchewan',
                                                                'Area outside census metropolitan areas and census agglomerations, Yukon',
                                                                'Ottawa - Gatineau (CMA), Ontario part, Ontario',
                                                                'Ottawa - Gatineau (CMA), Quebec part, Quebec'])].index).reset_index()
PE_Wrangled["GEO"] = PE_Wrangled["GEO"].str.replace(r'\(CMA\)', '').str.strip().str.replace(r' ,', ',').str.strip().str.replace(r' - ', '-').str.strip()
PE_Wrangled = PE_Wrangled.drop(PE_Wrangled[PE_Wrangled.GEO.isin(['Barrie, Ontario',
                                                                 'Abbotsford-Mission, British Columbia',
                                                                 'Kingston, Ontario',
                                                                 'Ottawa-Gatineau, Ontario/Quebec',
                                                                 'Saguenay, Quebec',
                                                                 'Brantford, Ontario',
                                                                 'Moncton, New Brunswick'])].index).drop(columns=["index"]) 
PE_Wrangled.to_csv("../data/processed/PE_Wrangled.csv")
PE_Wrangled
# Out:
# /var/folders/v9/f2hd85ns75q9chg2z10c7wcc0000gn/T/ipykernel_42164/2227833555.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   PE_Wrangled["GEO"] = PE_Wrangled["GEO"].str.replace(r'\(CMA\)', '').str.strip().str.replace(r' ,', ',').str.strip().str.replace(r' - ', '-').str.strip()
#          REF_DATE                                      GEO         Sex  \
# 0            2001    St. John's, Newfoundland and Labrador  Both sexes
# 1            2001    St. John's, Newfoundland and Labrador  Both sexes
# 2            2001    St. John's, Newfoundland and Labrador  Both sexes
# 3            2001    St. John's, Newfoundland and Labrador  Both sexes
# 4            2001    St. John's, Newfoundland and Labrador  Both sexes
# ...           ...                                      ...         ...
# 1199215      2022  Yellowknife (CA), Northwest Territories     Females
# 1199216      2022  Yellowknife (CA), Northwest Territories     Females
# 1199217      2022  Yellowknife (CA), Northwest Territories     Females
# 1199218      2022  Yellowknife (CA), Northwest Territories     Females
# 1199219      2022  Yellowknife (CA), Northwest Territories     Females
#
#                   Age group      UOM     VALUE
# 0                  All ages  Persons  176468.0
# 1              0 to 4 years  Persons    9317.0
# 2                   0 years  Persons    1839.0
# 3                    1 year  Persons    1880.0
# 4                   2 years  Persons    1785.0
# ...                     ...      ...       ...
# 1199215       0 to 14 years  Persons    2016.0
# 1199216      15 to 64 years  Persons    8283.0
# 1199217  65 years and older  Persons     884.0
# 1199218          Median age    Years      35.9
# 1199219         Average age    Years      36.0
#
# [1146090 rows x 6 columns]

# %%
pf2.unique_regions(PE_ordered_filtered_v2, PE_Wrangled, col_name='GEO')
# Out:
# [set(),
#  {'Alma (CA), Quebec',
#   'Arnprior (CA), Ontario',
#   'Baie-Comeau (CA), Quebec',
#   'Bathurst (CA), New Brunswick',
#   'Bay Roberts (CA), Newfoundland and Labrador',
#   'Belleville, Ontario',
#   'Brandon (CA), Manitoba',
#   'Brockville (CA), Ontario',
#   'Brooks (CA), Alberta',
#   'Campbell River (CA), British Columbia',
#   'Campbellton (CA), New Brunswick part, New Brunswick',
#   'Campbellton (CA), New Brunswick/Quebec',
#   'Campbellton (CA), Quebec part, Quebec',
#   'Camrose (CA), Alberta',
#   'Canmore (CA), Alberta',
#   'Cape Breton (CA), Nova Scotia',
#   'Carleton Place (CA), Ontario',
#   'Centre Wellington (CA), Ontario',
#   'Charlottetown (CA), Prince Edward Island',
#   'Chatham-Kent (CA), Ontario',
#   'Chilliwack (CA), British Columbia',
#   'Cobourg (CA), Ontario',
#   'Cold Lake (CA), Alberta',
#   'Collingwood (CA), Ontario',
#   'Corner Brook (CA), Newfoundland and Labrador',
#   'Cornwall (CA), Ontario',
#   'Courtenay (CA), British Columbia',
#   'Cowansville (CA), Quebec',
#   'Cranbrook (CA), British Columbia',
#   'Dawson Creek (CA), British Columbia',
#   'Dolbeau-Mistassini (CA), Quebec',
#   'Drummondville (CA), Quebec',
#   'Duncan (CA), British Columbia',
#   'Edmundston (CA), New Brunswick',
#   'Elliot Lake (CA), Ontario',
#   'Estevan (CA), Saskatchewan',
#   'Fort St. John (CA), British Columbia',
#   'Fredericton (CA), New Brunswick',
#   'Gander (CA), Newfoundland and Labrador',
#   'Granby (CA), Quebec',
#   'Grand Falls-Windsor (CA), Newfoundland and Labrador',
#   'Grande Prairie (CA), Alberta',
#   'Hawkesbury (CA), Ontario part, Ontario',
#   'Hawkesbury (CA), Ontario/Quebec',
#   'Hawkesbury (CA), Quebec part, Quebec',
#   'High River (CA), Alberta',
#   'Ingersoll (CA), Ontario',
#   'Joliette (CA), Quebec',
#   'Kamloops (CA), British Columbia',
#   'Kawartha Lakes (CA), Ontario',
#   'Kenora (CA), Ontario',
#   'Kentville (CA), Nova Scotia',
#   'Lachute (CA), Quebec',
#   'Lacombe (CA), Alberta',
#   'Leamington (CA), Ontario',
#   'Lethbridge, Alberta',
#   'Lloydminster (CA), Alberta part, Alberta',
#   'Lloydminster (CA), Alberta/Saskatchewan',
#   'Lloydminster (CA), Saskatchewan part, Saskatchewan',
#   'Matane (CA), Quebec',
#   'Medicine Hat (CA), Alberta',
#   'Midland (CA), Ontario',
#   'Miramichi (CA), New Brunswick',
#   'Moose Jaw (CA), Saskatchewan',
#   'Nanaimo (CA), British Columbia',
#   'Nelson (CA), British Columbia',
#   'New Glasgow (CA), Nova Scotia',
#   'Norfolk (CA), Ontario',
#   'North Battleford (CA), Saskatchewan',
#   'North Bay (CA), Ontario',
#   'Okotoks (CA), Alberta',
#   'Orillia (CA), Ontario',
#   'Owen Sound (CA), Ontario',
#   'Parksville (CA), British Columbia',
#   'Pembroke (CA), Ontario',
#   'Penticton (CA), British Columbia',
#   'Petawawa (CA), Ontario',
#   'Peterborough, Ontario',
#   'Port Alberni (CA), British Columbia',
#   'Port Hope (CA), Ontario',
#   'Portage la Prairie (CA), Manitoba',
#   'Powell River (CA), British Columbia',
#   'Prince Albert (CA), Saskatchewan',
#   'Prince George (CA), British Columbia',
#   'Prince Rupert (CA), British Columbia',
#   'Quesnel (CA), British Columbia',
#   'Red Deer (CA), Alberta',
#   'Rimouski (CA), Quebec',
#   'Rivière-du-Loup (CA), Quebec',
#   'Rouyn-Noranda (CA), Quebec',
#   'Saint John, New Brunswick',
#   'Saint-Georges (CA), Quebec',
#   'Saint-Hyacinthe (CA), Quebec',
#   'Sainte-Marie (CA), Quebec',
#   'Salaberry-de-Valleyfield (CA), Quebec',
#   'Salmon Arm (CA), British Columbia',
#   'Sarnia (CA), Ontario',
#   'Sault Ste. Marie (CA), Ontario',
#   'Sept-Îles (CA), Quebec',
#   'Shawinigan (CA), Quebec',
#   'Sorel-Tracy (CA), Quebec',
#   'Squamish (CA), British Columbia',
#   'Steinbach (CA), Manitoba',
#   'Stratford (CA), Ontario',
#   'Strathmore (CA), Alberta',
#   'Summerside (CA), Prince Edward Island',
#   'Swift Current (CA), Saskatchewan',
#   'Sylvan Lake (CA), Alberta',
#   'Terrace (CA), British Columbia',
#   'Thetford Mines (CA), Quebec',
#   'Thompson (CA), Manitoba',
#   'Thunder Bay, Ontario',
#   'Tillsonburg (CA), Ontario',
#   'Timmins (CA), Ontario',
#   'Truro (CA), Nova Scotia',
#   "Val-d'Or (CA), Quebec",
#   'Vernon (CA), British Columbia',
#   'Victoriaville (CA), Quebec',
#   'Wasaga Beach (CA), Ontario',
#   'Wetaskiwin (CA), Alberta',
#   'Weyburn (CA), Saskatchewan',
#   'Whitehorse (CA), Yukon',
#   'Williams Lake (CA), British Columbia',
#   'Winkler (CA), Manitoba',
#   'Wood Buffalo (CA), Alberta',
#   'Woodstock (CA), Ontario',
#   'Yellowknife (CA), Northwest Territories',
#   'Yorkton (CA), Saskatchewan'}]

# %% [markdown]
# ### Drop them!

# %%
PE_Wrangled_Final = PE_Wrangled.drop(PE_Wrangled[PE_Wrangled.GEO.isin(['Parksville (CA), British Columbia','Steinbach (CA), Manitoba','Moose Jaw (CA), Saskatchewan','Shawinigan (CA), Quebec','Owen Sound (CA), Ontario','Norfolk (CA), Ontario','Petawawa (CA), Ontario','Stratford (CA), Ontario','Baie-Comeau (CA), Quebec','Sault Ste. Marie (CA), Ontario','Dawson Creek (CA), British Columbia','Campbellton (CA), New Brunswick/Quebec','Medicine Hat (CA), Alberta','Weyburn (CA), Saskatchewan','North Bay (CA), Ontario','Camrose (CA), Alberta','Terrace (CA), British Columbia','Campbell River (CA), British Columbia','Rimouski (CA), Quebec','Cranbrook (CA), British Columbia','New Glasgow (CA), Nova Scotia','Nanaimo (CA), British Columbia','Saint-Hyacinthe (CA), Quebec','Winkler (CA), Manitoba','Wood Buffalo (CA), Alberta','Strathmore (CA), Alberta','Grand Falls-Windsor (CA), Newfoundland and Labrador','Wetaskiwin (CA), Alberta','Kawartha Lakes (CA), Ontario','Hawkesbury (CA), Quebec part, Quebec','Campbellton (CA), Quebec part, Quebec','Corner Brook (CA), Newfoundland and Labrador','Brandon (CA), Manitoba','Bay Roberts (CA), Newfoundland and Labrador','Kentville (CA), Nova Scotia','Rouyn-Noranda (CA), Quebec','Matane (CA), Quebec','Centre Wellington (CA), Ontario','Brooks (CA), Alberta','Truro (CA), Nova Scotia','Hawkesbury (CA), Ontario part, Ontario','Lloydminster (CA), Alberta/Saskatchewan','Campbellton (CA), New Brunswick part, New Brunswick','Charlottetown (CA), Prince Edward Island','Penticton (CA), British Columbia','Hawkesbury (CA), Ontario/Quebec','Lacombe (CA), Alberta','Granby (CA), Quebec','Woodstock (CA), Ontario','Edmundston (CA), New Brunswick','Rivière-du-Loup (CA), Quebec','Red Deer (CA), Alberta','Quesnel (CA), British Columbia','Whitehorse (CA), Yukon','Victoriaville (CA), Quebec','Sarnia (CA), Ontario','Joliette (CA), Quebec','Dolbeau-Mistassini (CA), Quebec','Port Alberni (CA), British Columbia','North Battleford (CA), Saskatchewan','Orillia (CA), Ontario','Bathurst (CA), New Brunswick','Okotoks (CA), Alberta','Prince Rupert (CA), British Columbia','Sorel-Tracy (CA), Quebec','Chatham-Kent (CA), Ontario','Cobourg (CA), Ontario','Lloydminster (CA), Alberta part, Alberta','Portage la Prairie (CA), Manitoba','Courtenay (CA), British Columbia','Lloydminster (CA), Saskatchewan part, Saskatchewan', 'Lethbridge, Alberta', "Val-d'Or (CA), Quebec", 'Cowansville (CA), Quebec', 'Miramichi (CA), New Brunswick', 'Midland (CA), Ontario', 'Sept-Îles (CA), Quebec', 'Alma (CA), Quebec', 'Peterborough, Ontario', 'Cape Breton (CA), Nova Scotia', 'Prince George (CA), British Columbia', 'Squamish (CA), British Columbia', 'Carleton Place (CA), Ontario', 'High River (CA), Alberta', 'Swift Current (CA), Saskatchewan', 'Vernon (CA), British Columbia', 'Williams Lake (CA), British Columbia', 'Kamloops (CA), British Columbia', 'Collingwood (CA), Ontario', 'Saint John, New Brunswick', 'Belleville, Ontario', 'Estevan (CA), Saskatchewan', 'Leamington (CA), Ontario', 'Salmon Arm (CA), British Columbia', 'Gander (CA), Newfoundland and Labrador', 'Pembroke (CA), Ontario', 'Timmins (CA), Ontario', 'Port Hope (CA), Ontario', 'Salaberry-de-Valleyfield (CA), Quebec', 'Yorkton (CA), Saskatchewan', 'Cornwall (CA), Ontario', 'Canmore (CA), Alberta', 'Thompson (CA), Manitoba', 'Ingersoll (CA), Ontario', 'Cold Lake (CA), Alberta', 'Prince Albert (CA), Saskatchewan', 'Powell River (CA), British Columbia', 'Sainte-Marie (CA), Quebec', 'Grande Prairie (CA), Alberta', 'Arnprior (CA), Ontario', 'Duncan (CA), British Columbia', 'Wasaga Beach (CA), Ontario', 'Brockville (CA), Ontario', 'Nelson (CA), British Columbia', 'Fredericton (CA), New Brunswick', 'Saint-Georges (CA), Quebec', 'Thunder Bay, Ontario', 'Elliot Lake (CA), Ontario', 'Kenora (CA), Ontario', 'Yellowknife (CA), Northwest Territories', 'Summerside (CA), Prince Edward Island', 'Chilliwack (CA), British Columbia', 'Fort St. John (CA), British Columbia', 'Tillsonburg (CA), Ontario', 'Lachute (CA), Quebec', 'Sylvan Lake (CA), Alberta', 'Thetford Mines (CA), Quebec', 'Drummondville (CA), Quebec'])].index).reset_index().drop(columns=["index"])
PE_Wrangled_Final.sample(15)
# Out:
#         REF_DATE                          GEO         Sex           Age group  \
# 112876      2015             Montréal, Quebec  Both sexes      50 to 54 years
# 144401      2019       Trois-Rivières, Quebec       Males            62 years
# 149060      2019             Calgary, Alberta  Both sexes            15 years
# 156126      2020           Winnipeg, Manitoba       Males            58 years
# 6538        2001             Calgary, Alberta     Females            80 years
# 4846        2001     Greater Sudbury, Ontario  Both sexes            12 years
# 126498      2016  Vancouver, British Columbia       Males          Median age
# 5114        2001     Greater Sudbury, Ontario     Females            44 years
# 71279       2009   Victoria, British Columbia       Males            77 years
# 152288      2020       Trois-Rivières, Quebec       Males            22 years
# 120629      2016       Trois-Rivières, Quebec       Males  90 years and older
# 66553       2009            Hamilton, Ontario     Females            68 years
# 12768       2002     Greater Sudbury, Ontario  Both sexes              1 year
# 59728       2008              London, Ontario  Both sexes      35 to 39 years
# 113809      2015             Toronto, Ontario     Females            60 years
#
#             UOM     VALUE
# 112876  Persons  313615.0
# 144401  Persons    1320.0
# 149060  Persons   16995.0
# 156126  Persons    5571.0
# 6538    Persons    1700.0
# 4846    Persons    2163.0
# 126498    Years      39.0
# 5114    Persons    1442.0
# 71279   Persons    1038.0
# 152288  Persons    1109.0
# 120629  Persons     403.0
# 66553   Persons    3037.0
# 12768   Persons    1494.0
# 59728   Persons   31942.0
# 113809  Persons   37359.0

# %%
PE_Wrangled_Final['REF_DATE'] = pd.to_datetime(PE_Wrangled_Final['REF_DATE'], format='%Y')
PE_Wrangled_Final.to_csv("../data/processed/PE_Wrangled_Final.csv")
PE_Wrangled_Final
# Out:
#          REF_DATE                                    GEO         Sex  \
# 0      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 1      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 2      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 3      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 4      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# ...           ...                                    ...         ...
# 174565 2022-01-01             Victoria, British Columbia     Females
# 174566 2022-01-01             Victoria, British Columbia     Females
# 174567 2022-01-01             Victoria, British Columbia     Females
# 174568 2022-01-01             Victoria, British Columbia     Females
# 174569 2022-01-01             Victoria, British Columbia     Females
#
#                  Age group      UOM     VALUE
# 0                 All ages  Persons  176468.0
# 1             0 to 4 years  Persons    9317.0
# 2                  0 years  Persons    1839.0
# 3                   1 year  Persons    1880.0
# 4                  2 years  Persons    1785.0
# ...                    ...      ...       ...
# 174565       0 to 14 years  Persons   24966.0
# 174566      15 to 64 years  Persons  139632.0
# 174567  65 years and older  Persons   52623.0
# 174568          Median age    Years      45.2
# 174569         Average age    Years      45.5
#
# [174570 rows x 6 columns]

# %% [markdown]
# Awesome. Thats a wrap for the PopEstimate dataset wrangling, now my groupmates have a wrangled and filtered set to use for their analysis. To continue processing, im going to now filter the dataset one more time by age to obtain the "all ages" value for each metropolitan area to plot on a line graph.

# %%
PE_Wrangled_Final_all_ages = PE_Wrangled_Final.drop(PE_Wrangled_Final[PE_Wrangled_Final['Age group'] != 'All ages'].index)
PE_Wrangled_Final_all_ages = PE_Wrangled_Final_all_ages.drop(PE_Wrangled_Final_all_ages[PE_Wrangled_Final['Sex'] != 'Both sexes'].index)
PE_Wrangled_Final_all_ages.reset_index()
PE_Wrangled_Final_all_ages
# Out:
# /var/folders/v9/f2hd85ns75q9chg2z10c7wcc0000gn/T/ipykernel_42164/3743727353.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   PE_Wrangled_Final_all_ages = PE_Wrangled_Final_all_ages.drop(PE_Wrangled_Final_all_ages[PE_Wrangled_Final['Sex'] != 'Both sexes'].index)
#          REF_DATE                                    GEO         Sex  \
# 0      2001-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 345    2001-01-01                   Halifax, Nova Scotia  Both sexes
# 690    2001-01-01                         Québec, Quebec  Both sexes
# 1035   2001-01-01                     Sherbrooke, Quebec  Both sexes
# 1380   2001-01-01                 Trois-Rivières, Quebec  Both sexes
# ...           ...                                    ...         ...
# 172845 2022-01-01                       Calgary, Alberta  Both sexes
# 173190 2022-01-01                      Edmonton, Alberta  Both sexes
# 173535 2022-01-01              Kelowna, British Columbia  Both sexes
# 173880 2022-01-01            Vancouver, British Columbia  Both sexes
# 174225 2022-01-01             Victoria, British Columbia  Both sexes
#
#        Age group      UOM      VALUE
# 0       All ages  Persons   176468.0
# 345     All ages  Persons   369252.0
# 690     All ages  Persons   705206.0
# 1035    All ages  Persons   183635.0
# 1380    All ages  Persons   143386.0
# ...          ...      ...        ...
# 172845  All ages  Persons  1608342.0
# 173190  All ages  Persons  1516719.0
# 173535  All ages  Persons   235473.0
# 173880  All ages  Persons  2842730.0
# 174225  All ages  Persons   423136.0
#
# [506 rows x 6 columns]

# %% [markdown]
# ### Visual EDA

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8,10))

pop = sns.lineplot(x='REF_DATE', y='VALUE', hue='GEO', data=PE_Wrangled_Final_all_ages, palette='colorblind')
plt.legend(title="GEO", loc="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel("Year")
plt.ylabel("Population Count")
plt.title("Population Counts in the most densely populated Canadian metropolitan areas over a 20 Year Span")
plt.show()

# %% [markdown]
# ### Final Data processing for PopEstimate set
# Okay, I have finally managed to visualize the change in population over time for each of the major metropolitan areas, however its hard to infer the actual change as the axis is quite dense to account for the vast differences in population sizes. I think I will instead create a new column for rate of change per year for each area.

# %%
rate_change_per_year = pd.DataFrame()
for city in PE_Wrangled_Final_all_ages["GEO"].unique():
    city_list = PE_Wrangled_Final_all_ages.loc[PE_Wrangled_Final_all_ages['GEO'] == city].copy()
    city_list['PE_RATE'] = city_list['VALUE'].pct_change() * 100
    city_list = city_list.dropna()
    rate_change_per_year = pd.concat([rate_change_per_year, city_list], axis=0)
rate_change_per_year
# Out:
#          REF_DATE                                    GEO         Sex  \
# 7935   2002-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 15870  2003-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 23805  2004-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 31740  2005-01-01  St. John's, Newfoundland and Labrador  Both sexes
# 39675  2006-01-01  St. John's, Newfoundland and Labrador  Both sexes
# ...           ...                                    ...         ...
# 142485 2018-01-01             Victoria, British Columbia  Both sexes
# 150420 2019-01-01             Victoria, British Columbia  Both sexes
# 158355 2020-01-01             Victoria, British Columbia  Both sexes
# 166290 2021-01-01             Victoria, British Columbia  Both sexes
# 174225 2022-01-01             Victoria, British Columbia  Both sexes
#
#        Age group      UOM     VALUE   PE_RATE
# 7935    All ages  Persons  177626.0  0.656210
# 15870   All ages  Persons  179026.0  0.788173
# 23805   All ages  Persons  181059.0  1.135589
# 31740   All ages  Persons  181720.0  0.365074
# 39675   All ages  Persons  183847.0  1.170482
# ...          ...      ...       ...       ...
# 142485  All ages  Persons  396839.0  1.580382
# 150420  All ages  Persons  403466.0  1.669947
# 158355  All ages  Persons  409398.0  1.470260
# 166290  All ages  Persons  413859.0  1.089649
# 174225  All ages  Persons  423136.0  2.241585
#
# [483 rows x 7 columns]

# %% [markdown]
# I also think I should calculate the total rate of change over the 20 year period for each metropolitan area. To do so, I created a new dataframe with a GEO column and a rate_total column and then populated the columns using the values from the GEO column in the wrangled dataset and created the total rate values using a for loop.

# %%
import warnings as w
w.filterwarnings("ignore", message="The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.")


total_rate_change = pd.DataFrame(columns=["GEO", "PE_rate_total"])

for city in PE_Wrangled_Final_all_ages["GEO"].unique():

    city_df = PE_Wrangled_Final_all_ages[PE_Wrangled_Final_all_ages["GEO"] == city]

    initial_pop = city_df.iloc[0]["VALUE"]
    final_pop = city_df.iloc[-1]["VALUE"]

    rate = (final_pop - initial_pop) / initial_pop * 100

    total_rate_change = total_rate_change.append({"GEO": city, "PE_rate_total": rate}, ignore_index=True)

total_rate_change = total_rate_change.sort_values('PE_rate_total').reset_index()
total_rate_change = total_rate_change.drop(columns=['index'])
total_rate_change
# Out:
#                                       GEO  PE_rate_total
# 0                Greater Sudbury, Ontario       6.788259
# 1                        Windsor, Ontario      12.064808
# 2         St. Catharines-Niagara, Ontario      14.969478
# 3                  Trois-Rivières, Quebec      16.979342
# 4                       Hamilton, Ontario      19.249163
# 5                          Québec, Quebec      20.358590
# 6                        Montréal, Quebec      20.737784
# 7   St. John's, Newfoundland and Labrador      24.169254
# 8                      Winnipeg, Manitoba      25.286061
# 9                      Sherbrooke, Quebec      25.822964
# 10                        London, Ontario      26.735099
# 11             Victoria, British Columbia      29.903111
# 12                   Halifax, Nova Scotia      30.150141
# 13                        Guelph, Ontario      34.169689
# 14                   Regina, Saskatchewan      35.706821
# 15                       Toronto, Ontario      36.926972
# 16            Vancouver, British Columbia      37.027564
# 17  Kitchener-Cambridge-Waterloo, Ontario      39.280704
# 18                        Oshawa, Ontario      44.868135
# 19                Saskatoon, Saskatchewan      49.467564
# 20              Kelowna, British Columbia      52.696323
# 21                      Edmonton, Alberta      57.599206
# 22                       Calgary, Alberta      64.489990

# %% [markdown]
# ### Data Visualizations
# Since the yearly rate of change is technically the derivative of the original data, I believe I can now plot it relative to dates and GEO locations in order to get the differentiated graph which should provide for a better visual than before.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,8))

pop = sns.lineplot(x='REF_DATE', y='PE_RATE', hue='GEO', data=rate_change_per_year, palette='colorblind')

plt.legend(title="GEO", loc="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel("Year")
plt.ylabel("population % change")
plt.title("Population percent change in the most densely populated Canadian metropolitan areas over a 20 Year Span")
plt.show()

# %% [markdown]
# Okay, having 20+ lines on one plot is hard to infer still, so I'll now split them up into individual lines using a facetgrid.

# %%
pop_facet = sns.FacetGrid(data=rate_change_per_year, col="GEO", col_wrap=4, height=3, palette="tab20c")
pop_facet.refline(y=0, linestyle=":")
pop_facet.map(plt.plot, "PE_RATE", marker="o")
pop_facet.fig.tight_layout(w_pad=1)
n=None

# %% [markdown]
# These look great! Since I have already calculated the total rate of population change over the 20 year period, I will now also plot that on a bar chart to get a clean representation.

# %%
total_rate_change.plot(x="GEO", y="PE_rate_total", kind="bar", figsize=(8, 6))
plt.title("Total Population percent Change per Metropolitan area")
plt.xlabel("Metropolitan area")
plt.ylabel("Total population % change")
plt.show()

# %% [markdown]
# Wow! After all this I have finally answered part of my research question! The fastest growing metropolitan area in Canada is Calgary, AB with Edmonton, AB and Kelowna, BC coming in 2nd and 3rd. In the future, I will conduct this same analysis using the wrangled NewHousingPriceIndex and to derive a definitive answer to which metropolitan hub is the most affordable respective to housing cost and inventory. It will be interesting to see if the top three hubs with respect to population growth will also be at the top with respect to cost.

# %% [markdown]
# ## Part 2, Working with HousingPriceIndex DF
# With the PopEst DF out of the way, I will now perform the same cleaning/processing/EDA for the HousingPriceIndex dataframe to eventually reach a workable dataset that has the same columns and filtered rows as PopEst, so that eventually I can merge the relevant columns into a single dataset for my dashboard. To start, I will pick up where I left off previously and filter out the non-conserved metropolitan areas in the NHPI DF.

# %%
NHPI_W_v3.sample(10)
# Out:
#        REF_DATE                                            GEO  \
# 6836 2015-03-01                               British Columbia
# 6412 2014-05-01                             Sherbrooke, Quebec
# 1297 2003-09-01  Ottawa-Gatineau, Ontario part, Ontario/Quebec
# 2907 2007-01-01                                 Prairie Region
# 1101 2003-04-01                St. Catharines-Niagara, Ontario
# 7029 2015-08-01                             Winnipeg, Manitoba
# 6787 2015-02-01                                 Prairie Region
# 2012 2005-03-01                             Sherbrooke, Quebec
# 3815 2008-12-01   Ottawa-Gatineau, Quebec part, Ontario/Quebec
# 2401 2006-01-01                                Atlantic Region
#
#      New housing price indexes                UOM  VALUE
# 6836    Total (house and land)  Index, 201612=100   93.6
# 6412    Total (house and land)  Index, 201612=100    NaN
# 1297    Total (house and land)  Index, 201612=100   74.9
# 2907    Total (house and land)  Index, 201612=100   89.1
# 1101    Total (house and land)  Index, 201612=100   65.1
# 7029    Total (house and land)  Index, 201612=100   97.3
# 6787    Total (house and land)  Index, 201612=100  100.8
# 2012    Total (house and land)  Index, 201612=100    NaN
# 3815    Total (house and land)  Index, 201612=100    NaN
# 2401    Total (house and land)  Index, 201612=100   75.5

# %%
pf2.unique_regions(NHPI_W_v3, PE_Wrangled_Final_all_ages, col_name='GEO')
# Out:
# [{'Alberta',
#   'Atlantic Region',
#   'British Columbia',
#   'Canada',
#   'Charlottetown, Prince Edward Island',
#   'Manitoba',
#   'New Brunswick',
#   'Newfoundland and Labrador',
#   'Nova Scotia',
#   'Ontario',
#   'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#   'Ottawa-Gatineau, Quebec part, Ontario/Quebec',
#   'Prairie Region',
#   'Prince Edward Island',
#   'Quebec',
#   'Saint John, Fredericton, and Moncton, New Brunswick',
#   'Saskatchewan'},
#  set()]

# %% [markdown]
# I believe I had already determined this in the prior part, however I needed a referesher. Now, I'll drop these from the NHPI_W_v3, create columns for the change in value per region over the time period and per year. Then I'll attempt to visualize what im working with.

# %%
NHPI_W_Final = NHPI_W_v3.drop(NHPI_W_v3[NHPI_W_v3.GEO.isin(['Alberta','Atlantic Region','British Columbia','Canada','Charlottetown, Prince Edward Island','Manitoba','New Brunswick','Newfoundland and Labrador','Nova Scotia','Ontario','Ottawa-Gatineau, Ontario part, Ontario/Quebec','Ottawa-Gatineau, Quebec part, Ontario/Quebec','Prairie Region','Prince Edward Island','Quebec','Saint John, Fredericton, and Moncton, New Brunswick','Saskatchewan'])].index).reset_index().drop(columns=["index"])
NHPI_W_Final.head(15)
# Out:
#      REF_DATE                                    GEO  \
# 0  2001-01-01  St. John's, Newfoundland and Labrador
# 1  2001-01-01                   Halifax, Nova Scotia
# 2  2001-01-01                         Québec, Quebec
# 3  2001-01-01                     Sherbrooke, Quebec
# 4  2001-01-01                 Trois-Rivières, Quebec
# 5  2001-01-01                       Montréal, Quebec
# 6  2001-01-01                        Oshawa, Ontario
# 7  2001-01-01                       Toronto, Ontario
# 8  2001-01-01                      Hamilton, Ontario
# 9  2001-01-01        St. Catharines-Niagara, Ontario
# 10 2001-01-01  Kitchener-Cambridge-Waterloo, Ontario
# 11 2001-01-01                        Guelph, Ontario
# 12 2001-01-01                        London, Ontario
# 13 2001-01-01                       Windsor, Ontario
# 14 2001-01-01               Greater Sudbury, Ontario
#
#    New housing price indexes                UOM  VALUE
# 0     Total (house and land)  Index, 201612=100   49.5
# 1     Total (house and land)  Index, 201612=100   66.3
# 2     Total (house and land)  Index, 201612=100   58.6
# 3     Total (house and land)  Index, 201612=100    NaN
# 4     Total (house and land)  Index, 201612=100    NaN
# 5     Total (house and land)  Index, 201612=100   59.4
# 6     Total (house and land)  Index, 201612=100    NaN
# 7     Total (house and land)  Index, 201612=100   55.8
# 8     Total (house and land)  Index, 201612=100   60.4
# 9     Total (house and land)  Index, 201612=100   61.1
# 10    Total (house and land)  Index, 201612=100   66.4
# 11    Total (house and land)  Index, 201612=100    NaN
# 12    Total (house and land)  Index, 201612=100   63.8
# 13    Total (house and land)  Index, 201612=100   92.8
# 14    Total (house and land)  Index, 201612=100   81.1

# %%
rate_change_per_year_NHPI = pd.DataFrame()
for city in NHPI_W_Final["GEO"].unique():
    city_list = NHPI_W_Final.loc[NHPI_W_Final['GEO'] == city].copy()
    city_list['NHPI_RATE'] = city_list['VALUE'].pct_change() * 100
    city_list = city_list.dropna()
    rate_change_per_year_NHPI = pd.concat([rate_change_per_year_NHPI, city_list], axis=0)
rate_change_per_year_NHPI.head(15)
# Out:
#       REF_DATE                                    GEO  \
# 23  2001-02-01  St. John's, Newfoundland and Labrador
# 46  2001-03-01  St. John's, Newfoundland and Labrador
# 69  2001-04-01  St. John's, Newfoundland and Labrador
# 92  2001-05-01  St. John's, Newfoundland and Labrador
# 115 2001-06-01  St. John's, Newfoundland and Labrador
# 138 2001-07-01  St. John's, Newfoundland and Labrador
# 161 2001-08-01  St. John's, Newfoundland and Labrador
# 184 2001-09-01  St. John's, Newfoundland and Labrador
# 207 2001-10-01  St. John's, Newfoundland and Labrador
# 230 2001-11-01  St. John's, Newfoundland and Labrador
# 253 2001-12-01  St. John's, Newfoundland and Labrador
# 276 2002-01-01  St. John's, Newfoundland and Labrador
# 299 2002-02-01  St. John's, Newfoundland and Labrador
# 322 2002-03-01  St. John's, Newfoundland and Labrador
# 345 2002-04-01  St. John's, Newfoundland and Labrador
#
#     New housing price indexes                UOM  VALUE  NHPI_RATE
# 23     Total (house and land)  Index, 201612=100   49.5   0.000000
# 46     Total (house and land)  Index, 201612=100   49.5   0.000000
# 69     Total (house and land)  Index, 201612=100   49.5   0.000000
# 92     Total (house and land)  Index, 201612=100   49.6   0.202020
# 115    Total (house and land)  Index, 201612=100   49.4  -0.403226
# 138    Total (house and land)  Index, 201612=100   50.6   2.429150
# 161    Total (house and land)  Index, 201612=100   50.6   0.000000
# 184    Total (house and land)  Index, 201612=100   50.6   0.000000
# 207    Total (house and land)  Index, 201612=100   50.6   0.000000
# 230    Total (house and land)  Index, 201612=100   50.6   0.000000
# 253    Total (house and land)  Index, 201612=100   50.6   0.000000
# 276    Total (house and land)  Index, 201612=100   50.6   0.000000
# 299    Total (house and land)  Index, 201612=100   51.2   1.185771
# 322    Total (house and land)  Index, 201612=100   51.4   0.390625
# 345    Total (house and land)  Index, 201612=100   51.3  -0.194553

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,8))

pop = sns.lineplot(x='REF_DATE', y='NHPI_RATE', hue='GEO', data=rate_change_per_year_NHPI, palette='colorblind')

plt.legend(title="GEO", loc="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel("Year")
plt.ylabel("Housing Value % change")
plt.title("Housing Value percent change in the most densely populated Canadian metropolitan areas over a 20 Year Span")
plt.show()

# %%
pop_facet1 = sns.FacetGrid(data=rate_change_per_year_NHPI, col="GEO", col_wrap=4, height=3, palette="tab20c")
pop_facet1.refline(y=0, linestyle=":")
pop_facet1.map(plt.plot, "NHPI_RATE", marker="o")
pop_facet1.fig.tight_layout(w_pad=1)
n=None

# %%
import warnings as w
w.filterwarnings("ignore", message="The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.")


total_rate_change_NHPI = pd.DataFrame(columns=["GEO", "NHPI_rate_total"])

for city in NHPI_W_Final["GEO"].unique():

    city_df = NHPI_W_Final[NHPI_W_Final["GEO"] == city]

    initial_value = city_df.iloc[0]["VALUE"]
    final_value = city_df.iloc[-1]["VALUE"]

    rate = (final_value - initial_value) / initial_value * 100

    total_rate_change_NHPI = total_rate_change_NHPI.append({"GEO": city, "NHPI_rate_total": rate}, ignore_index=True)

total_rate_change_NHPI = total_rate_change_NHPI.sort_values('NHPI_rate_total').reset_index()
total_rate_change_NHPI = total_rate_change_NHPI.drop(columns=['index'])
total_rate_change_NHPI
# Out:
#                                       GEO  NHPI_rate_total
# 0                Greater Sudbury, Ontario        49.691739
# 1              Victoria, British Columbia        50.060024
# 2                        Windsor, Ontario        59.267241
# 3             Vancouver, British Columbia        76.341128
# 4                    Halifax, Nova Scotia        84.012066
# 5                       Hamilton, Ontario        92.218543
# 6                        Toronto, Ontario       107.168459
# 7         St. Catharines-Niagara, Ontario       112.929624
# 8   St. John's, Newfoundland and Labrador       113.333333
# 9                          Québec, Quebec       115.187713
# 10                      Edmonton, Alberta       116.831683
# 11                        London, Ontario       130.564263
# 12                Saskatoon, Saskatchewan       132.548180
# 13  Kitchener-Cambridge-Waterloo, Ontario       139.156627
# 14                       Montréal, Quebec       155.387205
# 15                   Regina, Saskatchewan       170.105820
# 16                       Calgary, Alberta       189.327146
# 17                     Winnipeg, Manitoba       210.480349
# 18                     Sherbrooke, Quebec              NaN
# 19                 Trois-Rivières, Quebec              NaN
# 20                        Oshawa, Ontario              NaN
# 21                        Guelph, Ontario              NaN
# 22              Kelowna, British Columbia              NaN

# %% [markdown]
# This partially works, however I have NaN values for some of the major metro areas, so I'll modify the code to insteas locate the first and final non-NaN values instead of just using the first and last entries.

# %%
total_rate_change_NHPI_noNaN = pd.DataFrame(columns=["GEO", "NHPI_rate_total"])

for city in NHPI_W_Final["GEO"].unique():

    city_df = NHPI_W_Final[NHPI_W_Final["GEO"] == city]

    initial_value = city_df.loc[city_df["VALUE"].first_valid_index()]["VALUE"]
    final_value = city_df.loc[city_df["VALUE"].last_valid_index()]["VALUE"]

    rate = (final_value - initial_value) / initial_value * 100

    total_rate_change_NHPI_noNaN = total_rate_change_NHPI_noNaN.append({"GEO": city, "NHPI_rate_total": rate}, ignore_index=True)

total_rate_change_NHPI_noNaN = total_rate_change_NHPI_noNaN.sort_values('NHPI_rate_total').reset_index(drop=True)
total_rate_change_NHPI_noNaN
# Out:
#                                       GEO  NHPI_rate_total
# 0                  Trois-Rivières, Quebec        11.000000
# 1                      Sherbrooke, Quebec        11.500000
# 2                         Oshawa, Ontario        22.000000
# 3               Kelowna, British Columbia        23.400000
# 4                         Guelph, Ontario        24.000000
# 5                Greater Sudbury, Ontario        49.691739
# 6              Victoria, British Columbia        50.060024
# 7                        Windsor, Ontario        59.267241
# 8             Vancouver, British Columbia        76.341128
# 9                    Halifax, Nova Scotia        84.012066
# 10                      Hamilton, Ontario        92.218543
# 11                       Toronto, Ontario       107.168459
# 12        St. Catharines-Niagara, Ontario       112.929624
# 13  St. John's, Newfoundland and Labrador       113.333333
# 14                         Québec, Quebec       115.187713
# 15                      Edmonton, Alberta       116.831683
# 16                        London, Ontario       130.564263
# 17                Saskatoon, Saskatchewan       132.548180
# 18  Kitchener-Cambridge-Waterloo, Ontario       139.156627
# 19                       Montréal, Quebec       155.387205
# 20                   Regina, Saskatchewan       170.105820
# 21                       Calgary, Alberta       189.327146
# 22                     Winnipeg, Manitoba       210.480349

# %%
total_rate_change_NHPI_noNaN.plot(x="GEO", y="NHPI_rate_total", kind="bar", figsize=(8, 6))
plt.title("Total Housing Value percent Change per Metropolitan area")
plt.xlabel("Metropolitan area")
plt.ylabel("Total Housing Value % change")
plt.show()

# %% [markdown]
# After all this I have finally answered the second part of my research question! From the bar chart, I can see that Winnipeg has had the largest increase in housing price over 20 years, with Calgary and Regina coming in 2nd and 3rd place. Interestingly, Calgary had the largest change in population and also a large change in price. Kelowna, which was 3rd in population increase is 20th in housing price increase. I believe this may be due to Kelowna being a lake city, which would have kept the price high even 20 years ago as it is desirable.

# %% [markdown]
# ## Part 3, Working with NewInventory DF
#
# Now, I will be repeating the cleaning/processing detailed in part 1 and 2 with the final dataset needed for my analysis.

# %%
NewInventory.sample(5)
# Out:
#        REF_DATE                                    GEO         DGUID  \
# 199663  2004-06                       Saguenay, Quebec  2011S0503408
# 140411  1995-05              Census metropolitan areas           NaN
# 19146   1975-07                  Peterborough, Ontario  2011S0503529
# 65849   1983-08  St. John's, Newfoundland and Labrador  2011S0503001
# 256378  2013-03                Saskatoon, Saskatchewan  2011S0503725
#
#                  Housing estimates                    Type of unit    UOM  \
# 199663         Housing completions                       Row units  Units
# 140411         Housing completions           Single-detached units  Units
# 19146   Housing under construction           Single-detached units  Units
# 65849          Housing completions  Apartment and other unit types  Units
# 256378         Housing completions                       Row units  Units
#
#         UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE  STATUS  \
# 199663     300         units          0  v42127593      3.3.4      0     NaN
# 140411     300         units          0  v42127261      1.3.2   2927     NaN
# 19146      300         units          0  v42135873     37.2.2    200     NaN
# 65849      300         units          0  v42127399     18.3.5      0     NaN
# 256378     300         units          0  v42127413     19.3.4     21     NaN
#
#         SYMBOL TERMINATED  DECIMALS
# 199663     NaN        NaN         0
# 140411     NaN        NaN         0
# 19146      NaN        NaN         0
# 65849      NaN        NaN         0
# 256378     NaN        NaN         0

# %% [markdown]
# Looking at the data sample, I'll need to trim the erraneous columns, change the REF_DATE to datetime, filter the data to align with right date cutoff, include only Housing Completions, and keep only the top metro areas that I have conserved between the last two datasets.

# %%
NI_Wrangled = NewInventory.drop(columns=['DGUID', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'], axis=1).reset_index().drop(columns=["index"])

NI_Wrangled['REF_DATE'] = pd.to_datetime(NI_Wrangled['REF_DATE'])
NI_Wrangled = NI_Wrangled[~(NI_Wrangled['REF_DATE'] < '2001-01-01')].reset_index().drop(columns=["index"])

NI_Wrangled.head(10)
# Out:
#     REF_DATE                        GEO           Housing estimates  \
# 0 2001-01-01  Census metropolitan areas              Housing starts
# 1 2001-01-01  Census metropolitan areas              Housing starts
# 2 2001-01-01  Census metropolitan areas              Housing starts
# 3 2001-01-01  Census metropolitan areas              Housing starts
# 4 2001-01-01  Census metropolitan areas              Housing starts
# 5 2001-01-01  Census metropolitan areas  Housing under construction
# 6 2001-01-01  Census metropolitan areas  Housing under construction
# 7 2001-01-01  Census metropolitan areas  Housing under construction
# 8 2001-01-01  Census metropolitan areas  Housing under construction
# 9 2001-01-01  Census metropolitan areas  Housing under construction
#
#                      Type of unit    UOM  VALUE
# 0                     Total units  Units   7790
# 1           Single-detached units  Units   3455
# 2             Semi-detached units  Units    701
# 3                       Row units  Units    709
# 4  Apartment and other unit types  Units   2925
# 5                     Total units  Units  67549
# 6           Single-detached units  Units  23054
# 7             Semi-detached units  Units   4928
# 8                       Row units  Units   8592
# 9  Apartment and other unit types  Units  30975

# %%
NI_Wrangled_totals_completions = NI_Wrangled.drop(NI_Wrangled[NI_Wrangled['Housing estimates'] != 'Housing completions'].index)
NI_Wrangled_totals_completions = NI_Wrangled_totals_completions.drop(NI_Wrangled_totals_completions[NI_Wrangled['Type of unit'] != 'Total units'].index)
NI_Wrangled_totals_completions.reset_index().drop(columns=["index"])
# Out:
# /var/folders/v9/f2hd85ns75q9chg2z10c7wcc0000gn/T/ipykernel_42164/3895428860.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NI_Wrangled_totals_completions = NI_Wrangled_totals_completions.drop(NI_Wrangled_totals_completions[NI_Wrangled['Type of unit'] != 'Total units'].index)
#        REF_DATE                                   GEO    Housing estimates  \
# 0    2001-01-01             Census metropolitan areas  Housing completions
# 1    2001-01-01  Abbotsford-Mission, British Columbia  Housing completions
# 2    2001-01-01                       Barrie, Ontario  Housing completions
# 3    2001-01-01                    Brantford, Ontario  Housing completions
# 4    2001-01-01                      Calgary, Alberta  Housing completions
# ...         ...                                   ...                  ...
# 9499 2022-12-01                Trois-Rivières, Quebec  Housing completions
# 9500 2022-12-01           Vancouver, British Columbia  Housing completions
# 9501 2022-12-01            Victoria, British Columbia  Housing completions
# 9502 2022-12-01                      Windsor, Ontario  Housing completions
# 9503 2022-12-01                    Winnipeg, Manitoba  Housing completions
#
#      Type of unit    UOM  VALUE
# 0     Total units  Units   8518
# 1     Total units  Units     41
# 2     Total units  Units    148
# 3     Total units  Units      5
# 4     Total units  Units   1197
# ...           ...    ...    ...
# 9499  Total units  Units     93
# 9500  Total units  Units   1625
# 9501  Total units  Units    306
# 9502  Total units  Units     60
# 9503  Total units  Units    151
#
# [9504 rows x 6 columns]

# %%
pf2.unique_regions(NI_Wrangled_totals_completions, NHPI_W_Final, col_name='GEO')
# Out:
# [{'Abbotsford-Mission, British Columbia',
#   'Barrie, Ontario',
#   'Brantford, Ontario',
#   'Census metropolitan areas',
#   'Kingston, Ontario',
#   'Moncton, New Brunswick',
#   'Ottawa-Gatineau, Ontario part, Ontario/Quebec',
#   'Ottawa-Gatineau, Ontario/Quebec',
#   'Ottawa-Gatineau, Quebec part, Ontario/Quebec',
#   'Peterborough, Ontario',
#   'Saguenay, Quebec',
#   'Saint John, New Brunswick',
#   'Thunder Bay, Ontario'},
#  set()]

# %%
NI_Wrangled_Final = NI_Wrangled_totals_completions.drop(NI_Wrangled_totals_completions[NI_Wrangled_totals_completions.GEO.isin(['Abbotsford-Mission, British Columbia','Barrie, Ontario','Brantford, Ontario','Census metropolitan areas','Kingston, Ontario','Moncton, New Brunswick','Ottawa-Gatineau, Ontario part, Ontario/Quebec','Ottawa-Gatineau, Ontario/Quebec','Ottawa-Gatineau, Quebec part, Ontario/Quebec','Peterborough, Ontario','Saguenay, Quebec','Saint John, New Brunswick','Thunder Bay, Ontario'])].index).reset_index().drop(columns=["index"])
NI_Wrangled_Final.head(15)
# Out:
#      REF_DATE                                    GEO    Housing estimates  \
# 0  2001-01-01                       Calgary, Alberta  Housing completions
# 1  2001-01-01                      Edmonton, Alberta  Housing completions
# 2  2001-01-01               Greater Sudbury, Ontario  Housing completions
# 3  2001-01-01                        Guelph, Ontario  Housing completions
# 4  2001-01-01                   Halifax, Nova Scotia  Housing completions
# 5  2001-01-01                      Hamilton, Ontario  Housing completions
# 6  2001-01-01              Kelowna, British Columbia  Housing completions
# 7  2001-01-01  Kitchener-Cambridge-Waterloo, Ontario  Housing completions
# 8  2001-01-01                        London, Ontario  Housing completions
# 9  2001-01-01                       Montréal, Quebec  Housing completions
# 10 2001-01-01                        Oshawa, Ontario  Housing completions
# 11 2001-01-01                         Québec, Quebec  Housing completions
# 12 2001-01-01                   Regina, Saskatchewan  Housing completions
# 13 2001-01-01        St. Catharines-Niagara, Ontario  Housing completions
# 14 2001-01-01  St. John's, Newfoundland and Labrador  Housing completions
#
#    Type of unit    UOM  VALUE
# 0   Total units  Units   1197
# 1   Total units  Units    451
# 2   Total units  Units     11
# 3   Total units  Units     73
# 4   Total units  Units     55
# 5   Total units  Units    282
# 6   Total units  Units     25
# 7   Total units  Units    174
# 8   Total units  Units     84
# 9   Total units  Units    538
# 10  Total units  Units    237
# 11  Total units  Units     58
# 12  Total units  Units     57
# 13  Total units  Units     94
# 14  Total units  Units     81

# %% [markdown]
# Viola! Now, I have created a clean dataset for NewInventory. I'll now assess the rate of change on a yearly and total basis. Afterwards, I'll recreate the prior plots with this new data and make sense of it.

# %%
rate_change_per_year_NI = pd.DataFrame()
for city in NI_Wrangled_Final["GEO"].unique():
    city_list = NI_Wrangled_Final.loc[NI_Wrangled_Final['GEO'] == city].copy()
    city_list['NI_RATE'] = city_list['VALUE'].pct_change() * 100
    city_list = city_list.dropna()
    rate_change_per_year_NI = pd.concat([rate_change_per_year_NI, city_list], axis=0)
rate_change_per_year_NI
# Out:
#        REF_DATE                 GEO    Housing estimates Type of unit    UOM  \
# 23   2001-02-01    Calgary, Alberta  Housing completions  Total units  Units
# 46   2001-03-01    Calgary, Alberta  Housing completions  Total units  Units
# 69   2001-04-01    Calgary, Alberta  Housing completions  Total units  Units
# 92   2001-05-01    Calgary, Alberta  Housing completions  Total units  Units
# 115  2001-06-01    Calgary, Alberta  Housing completions  Total units  Units
# ...         ...                 ...                  ...          ...    ...
# 5979 2022-08-01  Winnipeg, Manitoba  Housing completions  Total units  Units
# 6002 2022-09-01  Winnipeg, Manitoba  Housing completions  Total units  Units
# 6025 2022-10-01  Winnipeg, Manitoba  Housing completions  Total units  Units
# 6048 2022-11-01  Winnipeg, Manitoba  Housing completions  Total units  Units
# 6071 2022-12-01  Winnipeg, Manitoba  Housing completions  Total units  Units
#
#       VALUE     NI_RATE
# 23      995  -16.875522
# 46      592  -40.502513
# 69     1092   84.459459
# 92      699  -35.989011
# 115    1026   46.781116
# ...     ...         ...
# 5979    332   12.542373
# 6002    176  -46.987952
# 6025    597  239.204545
# 6048    311  -47.906198
# 6071    151  -51.446945
#
# [6046 rows x 7 columns]

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,8))

pop = sns.lineplot(x='REF_DATE', y='NI_RATE', hue='GEO', data=rate_change_per_year_NI, palette='colorblind')

plt.legend(title="GEO", loc="center left", bbox_to_anchor=(1, 0.5))
plt.xlabel("Year")
plt.ylabel("New Housing Inventory % change")
plt.title("Housing Inventory percent change in the most densely populated Canadian metropolitan areas over a 20 Year Span")
plt.show()

# %%
pop_facet2 = sns.FacetGrid(data=rate_change_per_year_NI, col="GEO", col_wrap=4, height=3, palette="tab20c")
pop_facet2.refline(y=0, linestyle=":")
pop_facet2.map(plt.plot, "NI_RATE", marker="o")
pop_facet2.fig.tight_layout(w_pad=1)
n=None

# %%
pf2.calculate_total_rate_change_NI?
# Out:
# Signature: pf2.calculate_total_rate_change_NI(NI_Wrangled_Final)
# Docstring:
# Using the pandas dataframe `NI_Wrangled_Final` with columns "GEO" and "VALUE",
# calculates the total rate change for each unique "GEO" value.
#
# Returns:
# a pandas dataframe with columns "GEO" and "NI_rate_total", sorted in ascending order by "NI_rate_total".
# File:      ~/github-classroom/ubco-W2022T2-data301/project-group-group01/analysis/code/project_functions2.py
# Type:      function

# %%
total_rate_change_NI = pf2.calculate_total_rate_change_NI(NI_Wrangled_Final)
total_rate_change_NI
# Out:
#                                       GEO  NI_rate_total
# 0                        Toronto, Ontario    -334.266160
# 1                        Windsor, Ontario     -49.186312
# 2                         Guelph, Ontario     -35.133080
# 3   St. John's, Newfoundland and Labrador     -16.060837
# 4                Greater Sudbury, Ontario       1.003802
# 5                    Regina, Saskatchewan      41.155894
# 6                    Halifax, Nova Scotia      45.171103
# 7                         Oshawa, Ontario      63.239544
# 8   Kitchener-Cambridge-Waterloo, Ontario      69.262357
# 9                  Trois-Rivières, Quebec      72.273764
# 10                       Calgary, Alberta      77.292776
# 11                     Winnipeg, Manitoba      92.349810
# 12        St. Catharines-Niagara, Ontario      99.376426
# 13                Saskatoon, Saskatchewan     100.380228
# 14              Kelowna, British Columbia     142.539924
# 15                     Sherbrooke, Quebec     143.543726
# 16             Victoria, British Columbia     220.836502
# 17                      Hamilton, Ontario     235.893536
# 18                        London, Ontario     299.133080
# 19                         Québec, Quebec     755.863118
# 20                      Edmonton, Alberta     767.908745
# 21            Vancouver, British Columbia     920.486692
# 22                       Montréal, Quebec    2948.167300

# %%
total_rate_change_NI.plot(x="GEO", y="NI_rate_total", kind="bar", figsize=(8, 6))
plt.title("Total Housing Inventory percent Change per Metropolitan area")
plt.xlabel("Metropolitan area")
plt.ylabel("Total Housing Inventory % change")
plt.show()

# %% [markdown]
# After all this I have finally answered the third part of my research question! From the bar chart, I can infer that Montreal has has the highest inventory percent change of all metropolitan areas. Second is Vancouver, which makes sense since it always has construction going on and new multi-family living (i.e., Apartments, townhomes, duplexes, etc.) constructed yearly. Edmonton makes sense for the same reason, and also has more open land for building.

# %% [markdown]
# ### Part 4, relating the total rate changes to derive a measure of Metropolitan hub affordability
#
# Now that I have calculated the total rate changes for population, housing price, and housing inventory, I will first merge all total rates into a single dataset so that I can easily work with it for visualization or further anaylsis.

# %%
merged_rate_totals = pd.merge(total_rate_change, total_rate_change_NHPI_noNaN, on='GEO').merge(total_rate_change_NI, on='GEO')
merged_rate_totals
# Out:
#                                       GEO  PE_rate_total  NHPI_rate_total  \
# 0                Greater Sudbury, Ontario       6.788259        49.691739
# 1                        Windsor, Ontario      12.064808        59.267241
# 2         St. Catharines-Niagara, Ontario      14.969478       112.929624
# 3                  Trois-Rivières, Quebec      16.979342        11.000000
# 4                       Hamilton, Ontario      19.249163        92.218543
# 5                          Québec, Quebec      20.358590       115.187713
# 6                        Montréal, Quebec      20.737784       155.387205
# 7   St. John's, Newfoundland and Labrador      24.169254       113.333333
# 8                      Winnipeg, Manitoba      25.286061       210.480349
# 9                      Sherbrooke, Quebec      25.822964        11.500000
# 10                        London, Ontario      26.735099       130.564263
# 11             Victoria, British Columbia      29.903111        50.060024
# 12                   Halifax, Nova Scotia      30.150141        84.012066
# 13                        Guelph, Ontario      34.169689        24.000000
# 14                   Regina, Saskatchewan      35.706821       170.105820
# 15                       Toronto, Ontario      36.926972       107.168459
# 16            Vancouver, British Columbia      37.027564        76.341128
# 17  Kitchener-Cambridge-Waterloo, Ontario      39.280704       139.156627
# 18                        Oshawa, Ontario      44.868135        22.000000
# 19                Saskatoon, Saskatchewan      49.467564       132.548180
# 20              Kelowna, British Columbia      52.696323        23.400000
# 21                      Edmonton, Alberta      57.599206       116.831683
# 22                       Calgary, Alberta      64.489990       189.327146
#
#     NI_rate_total
# 0        1.003802
# 1      -49.186312
# 2       99.376426
# 3       72.273764
# 4      235.893536
# 5      755.863118
# 6     2948.167300
# 7      -16.060837
# 8       92.349810
# 9      143.543726
# 10     299.133080
# 11     220.836502
# 12      45.171103
# 13     -35.133080
# 14      41.155894
# 15    -334.266160
# 16     920.486692
# 17      69.262357
# 18      63.239544
# 19     100.380228
# 20     142.539924
# 21     767.908745
# 22      77.292776

# %%
columns = ['PE_rate_total', 'NHPI_rate_total', 'NI_rate_total']
sns.pairplot(merged_rate_totals[columns], kind='reg')
plt.show()

# %% [markdown]
# This offers a good plot for showing the correlation between the total population rate of change, housing price change, and housing inventory change. From the pairplot, one can infer that the correlation between new inventory is positively correlated to increasing housing costs, but slightly negatively correlated to increase population estimates, however the strength of correlation is low as indicated by the wide forecast of the blue shaded regions. As for increasing housing price, it is slightly positively correlated with increased population, but as before the correlation is weak and dependent on the metropolitan area. As for increasing population sizes, its slightly negatively correlated with new inventory and slightly positively correlated with increased housing price. All of this is explainable as supply and demand, as more people need residence, the cost of residence increases, therefore the need for new inventory increases but the availability will be bottlenecked by construction time and cost of construction, which in turn is limited by the rising housing cost, thus decreasing availability.
#
# I think I will now make an aggregated column for the total rate change score like the weighted score used in the pokemon index, whcih will then allow me to see the best and worst scored metropolitan areas

# %%
merged_rate_totals['aggregated_score'] = (merged_rate_totals['PE_rate_total']*0.5) + (merged_rate_totals['NHPI_rate_total']*0.3) + (merged_rate_totals['NI_rate_total']*0.2)
scored_metros = merged_rate_totals.sort_values('aggregated_score').reset_index().drop(columns=['index'])
scored_metros
# Out:
#                                       GEO  PE_rate_total  NHPI_rate_total  \
# 0                        Toronto, Ontario      36.926972       107.168459
# 1                        Windsor, Ontario      12.064808        59.267241
# 2                         Guelph, Ontario      34.169689        24.000000
# 3                Greater Sudbury, Ontario       6.788259        49.691739
# 4                  Trois-Rivières, Quebec      16.979342        11.000000
# 5                         Oshawa, Ontario      44.868135        22.000000
# 6   St. John's, Newfoundland and Labrador      24.169254       113.333333
# 7                      Sherbrooke, Quebec      25.822964        11.500000
# 8                    Halifax, Nova Scotia      30.150141        84.012066
# 9         St. Catharines-Niagara, Ontario      14.969478       112.929624
# 10              Kelowna, British Columbia      52.696323        23.400000
# 11             Victoria, British Columbia      29.903111        50.060024
# 12  Kitchener-Cambridge-Waterloo, Ontario      39.280704       139.156627
# 13                   Regina, Saskatchewan      35.706821       170.105820
# 14                      Hamilton, Ontario      19.249163        92.218543
# 15                Saskatoon, Saskatchewan      49.467564       132.548180
# 16                     Winnipeg, Manitoba      25.286061       210.480349
# 17                       Calgary, Alberta      64.489990       189.327146
# 18                        London, Ontario      26.735099       130.564263
# 19                         Québec, Quebec      20.358590       115.187713
# 20                      Edmonton, Alberta      57.599206       116.831683
# 21            Vancouver, British Columbia      37.027564        76.341128
# 22                       Montréal, Quebec      20.737784       155.387205
#
#     NI_rate_total  aggregated_score
# 0     -334.266160        -16.239208
# 1      -49.186312         13.975314
# 2      -35.133080         17.258228
# 3        1.003802         18.502412
# 4       72.273764         26.244424
# 5       63.239544         41.681976
# 6      -16.060837         42.872460
# 7      143.543726         45.070227
# 8       45.171103         49.312911
# 9       99.376426         61.238911
# 10     142.539924         61.876146
# 11     220.836502         74.136863
# 12      69.262357         75.239811
# 13      41.155894         77.116335
# 14     235.893536         84.468852
# 15     100.380228         84.574281
# 16      92.349810         94.257097
# 17      77.292776        104.501694
# 18     299.133080        112.363444
# 19     755.863118        195.908233
# 20     767.908745        217.430857
# 21     920.486692        225.513459
# 22    2948.167300        646.618514

# %%
scored_metros.plot(x="GEO", y="aggregated_score", kind="bar", figsize=(8, 6))
plt.title("Aggregated score per Metropolitan area")
plt.xlabel("Metropolitan area")
plt.ylabel("Aggregated Score")
plt.show()
